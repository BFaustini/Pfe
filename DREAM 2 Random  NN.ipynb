# %%
# Import numerical libraries.  
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, MultiLabelBinarizer

#Librairies
import time
import torch
import random

#Raccourcis utilisé
from tqdm import tqdm_notebook
import torch.nn as nn
import torch.utils.data as data_utils
import pandas as pd

# Import Keras
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
from tensorflow.keras.optimizers import SGD, RMSprop, Adam, Adadelta, Adamax, Nadam
from sklearn.model_selection import train_test_split
from math import exp
# Out:
# Using TensorFlow backend.

# %%
def to_array(X_AT_train, y_AT_train):
    training_in = np.empty([len(X_AT_train), 4872], dtype = float) #features inputs
    training_out = np.empty([len(y_AT_train), 1], dtype = float) #labels outputs
    for i in range(len(X_AT_train)): #1280
        training_out[i] = y_AT_train[i]
        for j in range(len(list_label)): #10
            training_in[i][j] = X_AT_train[list_label[j]][i]
    return(training_in, training_out)

# %%
def to_class(y_):
    res = np.zeros((len(y_), 11), dtype='q')
    for i in range(len(y_)):
        res[i][int(y_[i])] = 1
    return res

# %%
# Normalisation
sc = StandardScaler()

# %%
dfX = pd.read_csv('Molecular Dataset Dream 2.csv',sep=';')
dfY = pd.read_csv('Senteur Dataset Dream 2.csv',sep=';')

# %%
df = dfX.merge(dfY)

# %%
list_label = ['INTENSITY/STRENGTH', 'VALENCE/PLEASANTNESS', 'BAKERY', 'SWEET',
       'FRUIT', 'FISH', 'GARLIC', 'SPICES', 'COLD', 'SOUR', 'BURNT', 'ACID',
       'WARM', 'MUSKY', 'SWEATY', 'AMMONIA/URINOUS', 'DECAYED', 'WOOD',
       'GRASS', 'FLOWER', 'CHEMICAL']

dfY_ = df[['INTENSITY/STRENGTH']]
df = df.drop(list_label,axis=1)
df = df.drop('Unnamed: 0',axis=1)
df = df.drop('CID',axis=1)
colonne = list(df)

# %% [markdown]
# ## Keras

# %% [raw]
# Nb_param = [1000,1500,2000,2500,3000,3083]
# adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)

# %% [raw]
# for j in Nb_param:
#     print(j)
#     L = random.sample(colonne, k=j)
#     dfX = pd.DataFrame()
#
#     for i in L:
#         dfX['{}'.format(i)] = df['{}'.format(i)]
#     print("trainning for",j,"param")
#
#     dfY = dfY_
#     X_train = np.float32(dfX.values)
#     X_train = sc.fit_transform(X_train)
#     Y_train = np.float32(dfY.values)
#
#     x_train,x_test,y_train_,y_test_ = train_test_split(X_train,Y_train,test_size=0.1)
#     y_train = to_class(y_train_)
#     y_test = to_class(y_test_)
#     print("train")
#
#     a,b,c,d = j , j//2 , j//4 , j//8
#     print(a,b,c,d)
#
#     model = Sequential()
#     model.add(Dense( a , activation='relu', input_dim= a ))
#     model.add(Dense( b , activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense( c , activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense( d , activation='relu'))
#     model.add(Dropout(0.2))
#     model.add(Dense(11, activation='softmax'))
#
#
#     model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#     history = model.fit(x_train, y_train, epochs=25, batch_size=300, validation_data=(x_test,y_test), shuffle=True)
#     print("trained")
#     #  "Accuracy"
#     plt.plot(history.history['accuracy'])
#     plt.plot(history.history['val_accuracy'])
#     plt.title('model accuracy for {}'.format(j))
#     plt.ylabel('accuracy')
#     plt.xlabel('epoch')
#     plt.legend(['train', 'validation'], loc='upper left')
#     plt.show()

# %% [markdown]
# ## Pytorch

# %%
Epoch = 30
rand = 15
Nb_param = [30,300,1000,2000,3081]
ACC_30,ACC_300,ACC_1000,ACC_2000,ACC_3081 = [0]*Epoch,[0]*Epoch,[0]*Epoch,[0]*Epoch,[0]*Epoch
ACC = {30: ACC_30,300: ACC_300,1000: ACC_1000,2000: ACC_2000,3081: ACC_3081}
dfY = dfY_
dataY = np.longlong(dfY.values)
dataY = to_class(dataY)

for j in Nb_param:
    print("trainning for",j,"param :")
    Start_time = time.time()
    for z in range(rand):
        #pour faire des moyennes
        L = random.sample(colonne, k=j)
        dfX = pd.DataFrame()
        for i in L:
            dfX['{}'.format(i)] = df['{}'.format(i)]
        dataX = np.float32(dfX.values)
        dataX = sc.fit_transform(dataX)
        DATA_Train, DATA_Test, TARGET_Train, TARGET_Test = train_test_split(dataX, dataY ,test_size=0.1)

        Batch = 30
        X_train_tensor = torch.from_numpy(DATA_Train)
        Y_train_tensor = torch.from_numpy(TARGET_Train)
        X_test_tensor = torch.from_numpy(DATA_Test)
        Y_test_tensor = torch.from_numpy(TARGET_Test)

        train = data_utils.TensorDataset(X_train_tensor, Y_train_tensor)
        train_loader = data_utils.DataLoader(train, batch_size=Batch, shuffle=True)
        test = data_utils.TensorDataset(X_test_tensor, Y_test_tensor)
        test_loader = data_utils.DataLoader(test, batch_size=Batch, shuffle=True)

######################################################################################
        a,b,c,d = j , 2400 , 1200 , 600
        class MyNetwork(nn.Module):
            def __init__(self):
                super(MyNetwork, self).__init__()
                ## Activation layer
                self.relu = nn.ReLU()
                self.fc1 = nn.Linear(in_features = a, out_features = b)
                self.fc2 = nn.Linear(b, c)  
                self.fc3 = nn.Linear(c, d)
                self.output = nn.Linear( d , 11)
                self.softmax = nn.LogSoftmax(dim=1)
            def forward(self, x):
            ## First full connection
                x = self.fc1(x)
                x = self.relu(x)
            ## Second full connection
                x = self.fc2(x)
                x = self.relu(x)
            ## Third full connection
                x = self.fc3(x)
                x = self.relu(x)
            ## Output layer
                x = self.output(x)
                y = self.softmax(x)
                return y
############################################################################
        net = MyNetwork()
        net = net.cuda()
        LEARNING_RATE = 0.003
        MOMENTUM = 0.9
        criterion = nn.NLLLoss()
        optimizer = torch.optim.SGD(net.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
        N_EPOCHS = Epoch
        epoch_loss, epoch_acc, epoch_val_loss, epoch_val_acc = [], [], [], []
        start_time = time.time()
        for e in range(N_EPOCHS):
            running_loss = 0
            running_accuracy = 0
            running_acc=0
            start_epoch_time=time.time()
            net.train()
            for i, batch in enumerate(train_loader):
                x = batch[0]
                labels = batch[1]
                x = x.cuda()
                labels = labels.cuda()
                output = net(x)
                y = output
                loss = criterion(y, torch.max(labels, 1)[1])
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                with torch.no_grad():
                    running_loss += loss.item()            
                    running_accuracy += (y.max(1)[1] == torch.max(labels, 1)[1]).sum().item()
            epoch_loss.append(running_loss/len(train))
            epoch_acc.append(running_accuracy/len(train))
            
            net.eval()
            running_val_loss = 0
            running_val_accuracy = 0

            for i, batch in enumerate(test_loader):
                with torch.no_grad():
                    x = batch[0]
                    labels = batch[1]
                    x = x.cuda()
                    labels = labels.cuda()
                    output = net(x)
                    y = output
                    loss = criterion(y, torch.max(labels, 1)[1])
                    running_val_loss += loss.item()
                    running_val_accuracy += (y.max(1)[1] == torch.max(labels, 1)[1]).sum().item()
            epoch_val_loss.append(running_val_loss/len(test))
            epoch_val_acc.append(running_val_accuracy/len(test))
        inter = time.time() - start_time
        print("train",z+1," sur", Epoch,"epoch :",running_val_accuracy/len(test))
        print ('Temps en secondes:', inter )
        for u in range(Epoch):
            ACC[j][u] += epoch_acc[u] 
    for u in range(Epoch):
        ACC[j][u] = ACC[j][u]/rand
    interval = time.time() - Start_time  
    print ('Temps total en secondes pour',j,'parametres:', interval)
# Out:
# trainning for 30 param :
# train 1  sur 30 epoch : 0.12345679012345678
# Temps en secondes: 4.288970470428467
# train 2  sur 30 epoch : 0.18518518518518517
# Temps en secondes: 4.3070337772369385
# train 3  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 4.481122732162476
# train 4  sur 30 epoch : 0.1728395061728395
# Temps en secondes: 4.191425085067749
# train 5  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 4.1918134689331055
# train 6  sur 30 epoch : 0.19753086419753085
# Temps en secondes: 4.276559829711914
# train 7  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 4.877934455871582
# train 8  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 4.3083789348602295
# train 9  sur 30 epoch : 0.14814814814814814
# Temps en secondes: 4.151285648345947
# train 10  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 4.577274322509766
# train 11  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 4.097936153411865
# train 12  sur 30 epoch : 0.13580246913580246
# Temps en secondes: 4.124899387359619
# train 13  sur 30 epoch : 0.14814814814814814
# Temps en secondes: 4.038430690765381
# train 14  sur 30 epoch : 0.18518518518518517
# Temps en secondes: 4.012916326522827
# train 15  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 4.19438099861145
# Temps total en secondes pour 30 parametres: 64.85859274864197
# trainning for 300 param :
# train 1  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 4.10703444480896
# train 2  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 4.261280536651611
# train 3  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 4.370326519012451
# train 4  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 4.176544189453125
# train 5  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 4.115441799163818
# train 6  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 4.263525724411011
# train 7  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 4.1117448806762695
# train 8  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 4.103643417358398
# train 9  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 4.261529922485352
# train 10  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 4.193500280380249
# train 11  sur 30 epoch : 0.2222222222222222
# Temps en secondes: 4.080082893371582
# train 12  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 4.0887839794158936
# train 13  sur 30 epoch : 0.13580246913580246
# Temps en secondes: 6.472252130508423
# train 14  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 4.049042701721191
# train 15  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 4.121238708496094
# Temps total en secondes pour 300 parametres: 67.5026433467865
# trainning for 1000 param :
# train 1  sur 30 epoch : 0.18518518518518517
# Temps en secondes: 4.810777187347412
# train 2  sur 30 epoch : 0.19753086419753085
# Temps en secondes: 4.973374843597412
# train 3  sur 30 epoch : 0.1728395061728395
# Temps en secondes: 5.091807842254639
# train 4  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 5.2034077644348145
# train 5  sur 30 epoch : 0.13580246913580246
# Temps en secondes: 5.008310317993164
# train 6  sur 30 epoch : 0.24691358024691357
# Temps en secondes: 5.151020526885986
# train 7  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 5.009093284606934
# train 8  sur 30 epoch : 0.24691358024691357
# Temps en secondes: 5.142152309417725
# train 9  sur 30 epoch : 0.20987654320987653
# Temps en secondes: 5.341991901397705
# train 10  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 5.258023262023926
# train 11  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 5.460602760314941
# train 12  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 5.248284578323364
# train 13  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 5.01684308052063
# train 14  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 4.955852270126343
# train 15  sur 30 epoch : 0.06172839506172839
# Temps en secondes: 5.163104295730591
# Temps total en secondes pour 1000 parametres: 87.77049326896667
# trainning for 2000 param :
# train 1  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 5.594984292984009
# train 2  sur 30 epoch : 0.18518518518518517
# Temps en secondes: 5.6382012367248535
# train 3  sur 30 epoch : 0.14814814814814814
# Temps en secondes: 5.506011486053467
# train 4  sur 30 epoch : 0.2222222222222222
# Temps en secondes: 5.8368589878082275
# train 5  sur 30 epoch : 0.18518518518518517
# Temps en secondes: 5.746702671051025
# train 6  sur 30 epoch : 0.13580246913580246
# Temps en secondes: 5.7624733448028564
# train 7  sur 30 epoch : 0.04938271604938271
# Temps en secondes: 5.731897354125977
# train 8  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 5.65576434135437
# train 9  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 5.779799222946167
# train 10  sur 30 epoch : 0.13580246913580246
# Temps en secondes: 5.674108505249023
# train 11  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 5.707110643386841
# train 12  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 5.611525774002075
# train 13  sur 30 epoch : 0.07407407407407407
# Temps en secondes: 5.666861295700073
# train 14  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 5.648401498794556
# train 15  sur 30 epoch : 0.14814814814814814
# Temps en secondes: 5.515272617340088
# Temps total en secondes pour 2000 parametres: 108.33461117744446
# trainning for 3081 param :
# train 1  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 6.530992746353149
# train 2  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 6.510979413986206
# train 3  sur 30 epoch : 0.16049382716049382
# Temps en secondes: 6.356000661849976
# train 4  sur 30 epoch : 0.12345679012345678
# Temps en secondes: 6.323588609695435
# train 5  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 6.340432167053223
# train 6  sur 30 epoch : 0.18518518518518517
# Temps en secondes: 6.327013254165649
# train 7  sur 30 epoch : 0.04938271604938271
# Temps en secondes: 6.169384956359863
# train 8  sur 30 epoch : 0.14814814814814814
# Temps en secondes: 6.054049015045166
# train 9  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 6.037010669708252
# train 10  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 6.112460136413574
# train 11  sur 30 epoch : 0.1111111111111111
# Temps en secondes: 6.198536157608032
# train 12  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 6.120404243469238
# train 13  sur 30 epoch : 0.09876543209876543
# Temps en secondes: 6.194982290267944
# train 14  sur 30 epoch : 0.12345679012345678
# Temps en secondes: 6.144557952880859
# train 15  sur 30 epoch : 0.08641975308641975
# Temps en secondes: 6.329682350158691
# Temps total en secondes pour 3081 parametres: 131.2099106311798

# %%
plt.subplots(1,figsize=(16,4),constrained_layout=True)
line1, = plt.plot(ACC_30, label="30")
line2, = plt.plot(ACC_300, label="300")
line3, = plt.plot(ACC_1000, label="1000")
line4, = plt.plot(ACC_2000, label="2000")
line5, = plt.plot(ACC_3081, label="3081")
first_legend = plt.legend(handles=[line1,line2,line3,line4,line5], loc='upper left')
ax = plt.gca().add_artist(first_legend)
plt.show()
